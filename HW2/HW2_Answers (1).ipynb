# %% [markdown]
# /*** Deston Willis
# //*** Introduction to Data Science
# //*** September 21, 2023
# //*** HW2, Analyze data with Excel and SQL
#
#
# Problem 1:
#
# To replace the missing value in Assault I calculated the average of Assault and then replaced the missing value with that number (Approximately 170). I also checked for ouliers by finding the standard deviation for each attribute and then seeing if any values were more than 3 standard deviations away from the mean, which none of them were.
#
#
# USArrests data set:
#
# ![Screenshot (59).png](data:image/png;base64,...)
#
# Murder Rates for all States:
#
# ![Screenshot (48).png](data:image/png;base64,...)
#
# Histogram of Assaults:
#
# ![Screenshot (49).png](data:image/png;base64,...)
#
# Murder Rate vs Assault Rate:![Screenshot (50).png](data:image/png;base64,...)
#
# In SQL I used Update to replace all missing values with their averages. I then used Min, Max, Average, and Variance to find those values for each attribute. After that I used Select and Max to find the state with the highest Murder rate and used Order By to display the states in ascending order based on Urban Population. For the last question I found the Murder rate for Arizona and then used that value with Where to find out which states have higher Murder rates than Arizona.
#
# Problem 2:
#
# I once again found the averages for the different attributes and then replaced any missing values with their averages. After that I used the standard deviation to check if their were any outliers, which there were not.
#
# Child Mortality data set:
#
# ![Screenshot (56).png](data:image/png;base64,...)
#
# Under 5 vs Neonatal:
#
# ![Screenshot (51).png](data:image/png;base64,...)
#
# Infant vs Neonatal:
#
# ![Screenshot (52).png](data:image/png;base64,...)
#
# Year vs Infant:
#
# ![Screenshot (57).png](data:image/png;base64,...)
#
# In SQL I found the medians for all of the attributes and then replaced any missings values with them using Update. I then answered the questions in SQL by using Select all to display the table, Min and Max to find the min and max infant mortality rate, Select and Where to find the states that have above average Neonatal mortality rates, Order By to display infant mortality rates in descending order and Min, Max, Average, Variance, and Stdev to find those values for each mortality rate. I then used Alter Table to add the above 5 mortality rate column and used Update to fill in those values. I then used Select all again to display the new table.
